# %% [markdown]
# Name - Kauhsal Yadav                   Roll No. - 48
# Class - SYIT                             Batch - 00
# Date of Practical - 19-08-2026           Date of Submission - 19-08-2026

# %%
import pandas as pd

# %%
df = pd.read_csv("Students.csv")

# %% [markdown]
# Print top 5 values

# %%
print(df.head())
# Out:
#    Roll No     Name Department  Marks  Attendance
# 0      101     Amit     BSc IT     78          85
# 1      102   Aniket     BSc CS     65          90
# 2      103     Garv     BSc IT     88          92
# 3      104      Raj     BSc CS     72          80
# 4      105  Harshit     BSc IT     55          70

# %% [markdown]
# Print last 5 values

# %%
print(df.tail())
# Out:
#    Roll No     Name Department  Marks  Attendance
# 5      106  Kaushal     BSc CS     56          71
# 6      107      Jay     BSc IT     57          72
# 7      108    Rahul     BSc CS     58          73
# 8      109    Ayush     BSc IT     59          74
# 9      110     Alok     BSc CS     60          75

# %%
print(df.shape) #number of rows and columns
# Out:
# (10, 5)

# %%
print(df.columns)
# Out:
# Index(['Roll No', 'Name', 'Department', 'Marks', 'Attendance'], dtype='str')

# %%
print(df.dtypes)
# Out:
# Roll No       int64
# Name            str
# Department      str
# Marks         int64
# Attendance    int64
# dtype: object

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of    Roll No     Name Department  Marks  Attendance
# 0      101     Amit     BSc IT     78          85
# 1      102   Aniket     BSc CS     65          90
# 2      103     Garv     BSc IT     88          92
# 3      104      Raj     BSc CS     72          80
# 4      105  Harshit     BSc IT     55          70
# 5      106  Kaushal     BSc CS     56          71
# 6      107      Jay     BSc IT     57          72
# 7      108    Rahul     BSc CS     58          73
# 8      109    Ayush     BSc IT     59          74
# 9      110     Alok     BSc CS     60          75>

# %%
result = df[df["Attendance"]>=90]
print(result)
# Out:
#    Roll No    Name Department  Marks  Attendance
# 1      102  Aniket     BSc CS     65          90
# 2      103    Garv     BSc IT     88          92

# %%
result = df.sort_values("Marks")
print(result)
# Out:
#    Roll No     Name Department  Marks  Attendance
# 4      105  Harshit     BSc IT     55          70
# 5      106  Kaushal     BSc CS     56          71
# 6      107      Jay     BSc IT     57          72
# 7      108    Rahul     BSc CS     58          73
# 8      109    Ayush     BSc IT     59          74
# 9      110     Alok     BSc CS     60          75
# 1      102   Aniket     BSc CS     65          90
# 3      104      Raj     BSc CS     72          80
# 0      101     Amit     BSc IT     78          85
# 2      103     Garv     BSc IT     88          92

# %%
print("Maximum Marks ",df["Marks"].max())
print("Minimum Marks ",df["Marks"].min())
# Out:
# Maximum Marks  88
# Minimum Marks  55
