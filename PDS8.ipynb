# %% [markdown]
# **Name : Kaushal Yadav**
#
# **Class : SY.BscIT Batch : 00**
#
# **Date of Assignment:23/9/2026**
#
# **Date of Submission : 23/9/2026**
# Roll No:48

# %% [markdown]
# Write a Python program using BeautifulSoup to extract and print all headings from a webpage.

# %%
import requests

# %%
from bs4 import BeautifulSoup


url = "https://www.squarespace.com/blog/website-header-examples"

response = requests.get(url)


soup = BeautifulSoup(response.text, 'html.parser')


h2_headings = soup.find_all('h2')


for heading in h2_headings:
    print(heading.text.strip())
# Out:
# What is a website header?
# 1. Include the right elements
# 2. Establish clear visual hierarchy
# 3. Align with your brand identity
# 4. Optimize for mobile viewing
# 5. Customize based on website type
# 6. Test and refine your header design
# 4 website header examples
# 2. Condesa: Bold header design
# Related Articles
# Subscribe

# %% [markdown]
# Write a Python program using BeautifulSoup to extract all &lt;a&gt; tags and print their
# link text and URLs.

# %%
from bs4 import BeautifulSoup


url = "https://www.squarespace.com/blog/website-header-examples"


response = requests.get(url)


soup = BeautifulSoup(response.text, 'html.parser')


a_tags = soup.find_all('a')


for tag in a_tags:
    link_text = tag.text.strip()
    link_url = tag.get('href')


    if link_text and link_url:
        print(f"Text: {link_text} | URL: {link_url}")
# Out:
# Text: Skip to Main Content→ | URL: #content
# Text: Preise | URL: /preise
# Text: Log Out | URL: /
# Text: Get started→ | URL: /templates/get-started
# Text: Start a Free Trial→ | URL: /templates/get-started
# Text: Websites→ | URL: /website-design
# Text: Website Templates→ | URL: /templates
# Text: AI Website Builder→ | URL: /websites/ai-website-builder
# Text: Design Intelligence→ | URL: /design-intelligence
# Text: Ecommerce→ | URL: /ecommerce-website
# Text: Portfolios→ | URL: /websites/create-a-portfolio
# Text: Blogs→ | URL: /websites/create-a-blog
# Text: Analytics→ | URL: /websites/analytics
# Text: Services→ | URL: /services
# Text: Online Stores→ | URL: /online-stores
# Text: Invoicing→ | URL: /invoicing
# Text: Scheduling→ | URL: /scheduling
# Text: Limited Releases→ | URL: /ecommerce/limited-release-selling
# Text: Content & Memberships→ | URL: /content
# Text: Donations→ | URL: /donations
# Text: Financial Solutions→ | URL: /financial-solutions
# ...

# %% [markdown]
# Create a Seaborn bar chart showing the sales of 5 different products.

# %%
# !pip install seaborn

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt


products = ['Laptop', 'LED TV', 'Mobile', 'Refrigerator', 'Computer']
sales = [350, 220, 480, 150, 310]


sns.set_theme(style="whitegrid")


plt.figure(figsize=(8, 5))
sns.barplot(x=products, y=sales, palette="muted")


plt.xlabel('Products', fontsize=12)
plt.ylabel('Sales Count', fontsize=12)
plt.title('Sales of 5 Different Products', fontsize=14)


plt.show()
# Out:
# /tmp/ipykernel_1210/2625892949.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=products, y=sales, palette="muted")

# %% [markdown]
# Create a Seaborn scatter plot showing the relationship between students' study hours and their marks.

# %%
import matplotlib.pyplot as plt
import seaborn as sns


study_hours = [2, 3, 4, 5, 6, 7, 8, 9]
marks = [50, 55, 65, 70, 75, 85, 90, 95]


sns.scatterplot(x=study_hours, y=marks)


plt.xlabel('Study Hours')
plt.ylabel('Marks')

plt.show()

# %% [markdown]
# Create a Seaborn histogram to display the distribution of students' marks

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.displot([45, 55, 65, 75, 85, 95], kind="hist")

plt.show()
